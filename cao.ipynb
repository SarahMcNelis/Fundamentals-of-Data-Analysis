# %% [markdown]
# ![cao](img/cao.png)

# %% [markdown]
# <br>
#
# # CAO Points Analysis
#
# [Official CAO Website](https://www.cao.ie/)
#
# ***

# %% [markdown]
# ## Overview
# ***
#
# This notebook analyses the CAO points from the last three years by converting the following:
#
#
# - 2021 points from http into a csv file and then into dataframe.
#
# - 2020 points from an excel spreadsheet into a csv file and then into another dataframe.
#
# - 2019 points from a pdf into another csv file and then into another dataframe.
#
#
#
# Then I combine all three dateframes into one dataframe for analysis.
#
# <br>

# %% [markdown]
# ## Importing modules
# ***

# %% [markdown]
# ### Regular Expressions
# Regular expression also known as [regexes](https://realpython.com/regex-python/) are special sequence of characters that are used to form a search pattern. In other words, a user can use a regular expression to search through a particular file in order to find that particular pattern or sequence. Python has a built-package for regular expressions called "[re](https://docs.python.org/3/library/re.html)".

# %% [markdown]
# ### Requests
# This is another built-in package in python. [Requests](https://www.pythonforbeginners.com/requests/using-requests-in-python) is imported to allow a user to send HTTP/1.1 requests. To put it simply, this module contains various functions and operations that allow the user to retrieve data from a http.

# %% [markdown]
# ### Datetime
# The [datetime module](https://www.geeksforgeeks.org/python-datetime-module/) is imported when working with dates and times. There are six main categories in this module:
#
# 1. date - used for year, month or day.
#
#
# 2. time - used for hours, minutes, seconds, microseconds, and tzinfo.
#
#
# 3. datetime - is a combination of both date and time.
#
#
# 4. timedelta - used to represent duration.
#
#
# 5. tzinfo - gives time zone information objects.
#
#
# 6. timezone – gives tzinfo as fixed offset from UTC.

# %% [markdown]
# ### Pandas
# [Pandas](https://mode.com/python-tutorial/libraries/pandas/#:~:text=Pandas%20is%20a%20Python%20library%20for%20data%20analysis.&text=Pandas%20is%20built%20on%20top,NumPy%27s%20methods%20with%20less%20code.) is another python library used for data analysis. It uses dataframes and operations to manipulate numerical tables and time series. Pandas will be used in this notebook to store and compare the cao points from 2021, 2020 and 2019.

# %% [markdown]
# ### Urllib request
# This is an [extensive library](https://docs.python.org/3/library/urllib.request.html) used for opening urls. Unlike the requests library, this module offers more functionality and quicker way to open and read data from urls.

# %% [markdown]
# ### Matplotlib pyplot
# This is another python library used for data visualisation. [Matplotlib pyplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html) is a state based interface. In other words, it keeps track of the current state and automatically updates it instead of having to assign an object. It is a convenient way for users to generate high quality plots with minimal effort.
#
# <br>

# %%
# For regular expressions. - ref 1.
import re

# Convenient HTTP requests - ref 4.
import requests as rq

# Dates and times. - ref 8. 
import datetime as dt

# Pandas for data frames. - ref 9.
import pandas as pd

# For downloading urls. - ref 10.
import urllib.request as urlrq

# For plotting. 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Size and Design
# ***

# %% [markdown]
# ### [Magic Commands](https://towardsdatascience.com/top-10-magic-commands-in-python-to-boost-your-productivity-1acac061c7a9)
# Here I use the magic command [%matplotlib inline](https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline) which renders any plots created within this notebook inline instead of opening on an external window.
#
#
# ### [Style Sheets](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)
# I am selecting the style sheet fivethirtyeight in this notebook as it allows for clear and attractive plots. This is done using the style.use function.
#
#
# ### [Figure Size](https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.RcParams)
# Without this function the plots rendered in this notebook are too small. I ahve set a decent figure size here for all the plots within this notebook.

# %%
#Using magic command to set plots to display inline.
# %matplotlib inline

# Change figure style. 
plt.style.use('fivethirtyeight')

# Change default figure size.
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# <br>
#
# ## Time stamp
# ***

# %% [markdown]
# Here I created a time stamp by getting the current date and time using the datetime module. Next the strftime function is used to take in the current date and time and convert it into a string using the strftime method. There are numerious formats that can be used. A list of the strftime format can be found [here](https://strftime.org/).
#
#
# In the code cell below, I take the current date and time and convert it into the following format. This will then be used as the time stamp going forward.
#
# - %Y stands for the year as a decimal number.
#
#
# - %m represents the month as a decimal number.
#
#
# - %d is for the day of the month as a decimal number.
#
#
# - %H gives the hour in a 24 hour clock format.
#
#
# - %M is used to get the minute as a decimal number.
#
#
# - %S produces the second as a decimal number.

# %%
# Get the current date and time.
now = dt.datetime.now()

# Format as a string.
nowstr = now.strftime('%Y%m%d_%H%M%S')

# %% [markdown]
# <br>
#
# # 2021 CAO Points
#
# http://www.cao.ie/index.php?page=points&p=2021
# ***

# %% [markdown]
# This section converts the 2021 CAO points from a http link into a pandas dataframe.
#
# <br>

# %% [markdown]
# ### Request the http link
# ***

# %% [markdown]
# In the code cell below, [requests.get](https://docs.python-requests.org/en/latest/user/quickstart/#make-a-request) is used to fetch the data from the selected http link.
#
#
# It is also good practice to check the http respone. This is done by call `resp`. As you can see the returned respone is 200 which means the request was successful. A list of different response codes can be found [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status)

# %%
# Fetch the 2021 CAO points URL - ref 4.
resp = rq.get('http://www2.cao.ie/points/l8.php')

# Check response. 200 means OK. 401 means error. 
resp
# Out:
# <Response [200]>

# %% [markdown]
# <br>
#
# ### Save origional data set
# ***

# %% [markdown]
# Here I use the time stamp I created above to open a file path for the origional http data. It will be stored in the data folder in this repository and the time stamp is used in the filename in order to keep track of the data each time the code is run in case an error ever occurs.

# %%
# Create a file path for the original data.
pathhtml = 'data/cao2021_' + nowstr + '.html'

# %% [markdown]
# <br>
#
# ### Error on server
# ***

# %% [markdown]
# [Encoding](https://stackoverflow.com/questions/4657416/difference-between-encoding-and-encryption) is used to transfer data in a safe way so that it can be used on different systems. The encoding on my machine may differ from anothers which is why we need to decode using the method of that particular server.
#
#
# The server says we should decode as per:
#
# ```Content-Type: text/html; charset=iso-8859-1```
#
#
# However, an error occured. One of the lines uses \x96 which isn't defined in iso-8859-1. This error was referring to a fada in one of the Irish course names.
#
#
# Therefore, we need to use a similar decoding standard [cp1252](https://en.wikipedia.org/wiki/Windows-1252#:~:text=Windows%2D1252%20or%20CP%2D1252,Spanish%2C%20French%2C%20and%20German.) instead. This encoding method includes characters from the Latin alphabet which would include fadas.

# %%
# The server uses the wrong encoding.
original_encoding = resp.encoding

# Change encoding here. 
resp.encoding = 'cp1252'

# %% [markdown]
# <br>
#
# Using a [with statement](https://www.pythonforbeginners.com/files/with-statement-in-python) here to open file created above and write the above request to that file.

# %%
# Open and write origional http data to file.
with open(pathhtml, 'w') as f:
    f.write(resp.text)

# %% [markdown]
# <br>
#
# ### Regular Expressions
# ***

# %% [markdown]
# Using a regular expression here to select the desired lines within the http file.  This [blog](https://www.mygreatlearning.com/blog/regular-expression-in-python/) gives very clear explaination of characters used when working with regular expressions. In the code cell below:
#
#
# - [re.compile](https://www.tutorialspoint.com/Why-do-we-use-re-compile-method-in-Python-regular-expression) collects a regular expression pattern into pattern objects.
#
#
# - The [r](https://developers.google.com/edu/python/regular-expressions#:~:text=The%20%27r%27%20at%20the%20start,needs%20this%20feature%20badly!) at the start of the regular expression below refers to the start of the pattern string.
#
#
# - The letters or numbers inside the square brackets set what you are searching for.
#
#
# - The number within the braces set the amount of characters to search for.
#
#
# - An important note here is the use of two blank spaces as part of this regualr expression. If these characters were not added then the expression would not work correctly.
#
#
# - Finally, the full stop look for any character, except for a new line and the asterisk looks to match the preceding characters zero or more times.

# %%
# Compile the regular expression for matching lines.
re_course = re.compile(r'([A-Z]{2}[0-9]{3})  (.*)')

# %% [markdown]
# <br>
#
# ### Loop through the lines of the response
# ***

# %% [markdown]
# This funciton is used to seperate the points from the # and * characters and then store them in an array.
#
# - First the variable portfolio is created for the # characters. The origional http file told us that # represents if there was a entry test, interview, portfolio or audition for the course. An [if statement](https://www.w3schools.com/python/python_conditions.asp) is used in this function to see if any value is equal to the # symbol and then stores it in the portofio variable.
#
#
# - Next the random variable checks for * characters. This informs us that not all on this points score were offered places.
#
#
# - Finally the [isdigit](https://www.w3schools.com/python/ref_string_isdigit.asp) function is used to check if any of the characters in the text are digits and stores them in the points variable.

# %%
# Creating a function to seperate and add points # and * to an array.
def points_to_array(s):
    portfolio = ''
    if s[0] == '#':
        portfolio = '#'
        
    random = ''
    if s[-1] == '*':
        random = '*'
        
    points = ''
    
    for i in s:
        if i.isdigit():
            # not addition but linking these two things together 
            points = points + i 
            
    return[points, portfolio, random]

points_to_array
# Out:
# <function __main__.points_to_array(s)>

# %%
# Creating a path for new 2021 points as a csv file.
path2021 = 'data/cao2021_csv_' + nowstr + '.csv'

# %% [markdown]
# <br>
#
# In the code cell below:
#
# - [iter_lines](https://stackoverflow.com/questions/16870648/python-read-website-data-line-by-line-when-available) is a function in the requests library which reads the data line by line. It is better to take small bits of data at a time in to avoid losing anything.
#
#
# - [fullmatch](https://www.geeksforgeeks.org/re-fullmatch-function-in-python/) returns a match object if the whole string matches the regular expression pattern.
#
#
# - [strip](https://www.w3schools.com/python/ref_string_strip.asp) is used to remove spaces or characters either a the beginning or the end of a string. So far the first five values are assigned to the course_code variable. Next the strip function is used to extract characters from the seventh value up until the fifty seventh value and this is set to the course_title.
#
#
# - [re.split](https://stackoverflow.com/questions/12683201/python-re-split-to-split-by-spaces-commas-and-periods-but-not-in-cases-like) returns a list where the string is split at each match. In other words, the points are split using the regular expression and the plus symbol will match one or more of that pattern. So this splits the points into round 1 and round 2.
#
#
# - [len](https://www.w3schools.com/python/ref_func_len.asp) is used to check if the length of the course list is not equal to two then only return first two values.
#
# <br>
#
# Now the amended 2021 points with only the information I want is written to a new csv file that can be used for analysis.

# %%
# Keeps track of how many courses we process.
no_lines = 0

# Open the csv file for writing.
with open(path2021, 'w') as f:
    # Write a header row for columns.
    f.write(','.join(['code', 'title', 'pointsR1', 'pointsR2']) + '\n')
    
    # Loop through lines of the response - ref 6.
    for line in resp.iter_lines():
        
        # Decode the line, using the wrong encoding!
        dline = line.decode('cp1252')
        
        # Match only the lines representing courses.
        if re_course.fullmatch(dline):
            
            # Add one to the lines counter.
            no_lines = no_lines + 1
            
            #extract first 5 characters for course codes.
            course_code = dline[:5]
            
            # strip everything before 7  and after 57
            course_title = dline[7:57].strip()
            
            #course_round1 = dline[60:]
            #print(f"'{course_code} {len(dline)}'")
            
            course_points = re.split(' +', dline[60:])
            #print(f"'{course_code} {course_points}'")
            
            # if the length of points is not equal to 2 only return first 2 values. 
            if len(course_points) != 2:
                
                # prints out line which contains 3 course points. 
                # print(f"'{course_code} {course_points}'")
                
                course_points = course_points[:2]
                
            # join the fields using a comma.
            linesplit = [course_code, course_title, course_points[0], course_points[1]]
            
            # Rejoin the substrings with commas in between.
            f.write(','.join(linesplit) + '\n')
               
# Print the total number of processed lines.
print(f"Total number of lines is {no_lines}.")
# Out:
# Total number of lines is 949.

# %% [markdown]
# <br>
#
# **NB**: It was verified as of 03/12/21 that there were 949 courses exactly on the CAO 2021 points list.
#
# <br>

# %% [markdown]
# Finally, the last step is to assign path2021 to a pandas dataframe: df2021.
#
# <br>

# %%
# Assign variable and read new dataframe.
df2021 = pd.read_csv(path2021, encoding='cp1252')

# %%
df2021
# Out:
#       code                                              title pointsR1  \
# 0    AL801     Software Design for Virtual Reality and Gaming      300
# 1    AL802  Software Design in Artificial Intelligence for...      313
# 2    AL803  Software Design for Mobile Apps and Connected ...      350
# 3    AL805    Computer Engineering for Network Infrastructure      321
# 4    AL810                                 Quantity Surveying      328
# ..     ...                                                ...      ...
# 944  WD211                                 Creative Computing      270
# 945  WD212                    Recreation and Sport Management      262
# 946  WD230           Mechanical and Manufacturing Engineering      230
# 947  WD231                 Early Childhood Care and Education      266
# 948  WD232                       Business Information Systems      261
#
#     pointsR2
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# ...

# %%
# Check random location in df2021.
df2021.iloc[160:180]
# Out:
#       code                                           title pointsR1 pointsR2
# 160  CK600                                     Engineering      510     509*
# 161  CK606   Architecture - Offered jointly by UCC and CIT      543      NaN
# 162  CK701  Medicine (Undergraduate Entry - HPAT required)     #738    #737*
# 163  CK702                                       Dentistry     625*     625*
# 164  CK703                                        Pharmacy     613*     613*
# 165  CK704                            Occupational Therapy     601*      NaN
# 166  CK705                     Speech and Language Therapy      568     566*
# 167  CK706                          Public Health Sciences      500      NaN
# 168  CK707                     Medical and Health Sciences     578*      NaN
# 169  CK710                                 General Nursing     498*     497*
# 170  CK712     Children`s and General Nursing (Integrated)      565      NaN
# ...

# %% [markdown]
# However, here we can immediately see that the '*' and '#' symbols are still present in this dataframe. After some rearch I came across a blog from 5 years ago, found [here](https://stackoverflow.com/questions/38277928/remove-special-characters-in-pandas-dataframe), where someone had a similar issue with their dataframe. I decided to incorporate this piece of code into my own notebook to see if it would remove the special characters so that my dataframe only contains the actual points of each course.

# %% [markdown]
# This is done using the pandas [replace](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html) function which can replace any string or numeric value with another. In the below code cell, I am using this function to replace the '*' and '#' symbols with an empty string.

# %%
# Replace * and # characters for 2021 r1 and r2. 
df2021['pointsR1'] = df2021['pointsR1'].replace('\*', '', regex=True)
df2021['pointsR1'] = df2021['pointsR1'].replace('\#', '', regex=True)
df2021['pointsR2'] = df2021['pointsR2'].replace('\*', '', regex=True)
df2021['pointsR2'] = df2021['pointsR2'].replace('\#', '', regex=True)

# %%
# Double check code worked. 
df2021.iloc[160:180]
# Out:
#       code                                           title pointsR1 pointsR2
# 160  CK600                                     Engineering      510      509
# 161  CK606   Architecture - Offered jointly by UCC and CIT      543      NaN
# 162  CK701  Medicine (Undergraduate Entry - HPAT required)      738      737
# 163  CK702                                       Dentistry      625      625
# 164  CK703                                        Pharmacy      613      613
# 165  CK704                            Occupational Therapy      601      NaN
# 166  CK705                     Speech and Language Therapy      568      566
# 167  CK706                          Public Health Sciences      500      NaN
# 168  CK707                     Medical and Health Sciences      578      NaN
# 169  CK710                                 General Nursing      498      497
# 170  CK712     Children`s and General Nursing (Integrated)      565      NaN
# ...

# %%
# Save new df to data folder in repo.
df2021.to_csv(path2021)

# %% [markdown]
# Now the 2021 points are ready for analysis
#
# <br>
#
# ***

# %% [markdown]
# <br>
#
# # 2020 CAO Points
#
# http://www.cao.ie/index.php?page=points&p=2020
#
# ***

# %% [markdown]
# This section converts the 2020 CAO points from an excel file into a pandas dataframe.
#
# <br>

# %% [markdown]
# ### Save origional data set
#
# ***

# %% [markdown]
# Once again the time stamp is used here when saving the origional excel file to my data folder in this repository. The urllib requests function [urlretrieve](https://programmer.ink/think/how-to-use-urlretrieve-in-python-3.html) is used here to download this remote excel file to my local machine.

# %%
# Create variable for url.
url2020 = 'http://www2.cao.ie/points/CAOPointsCharts2020.xlsx'

# %%
# Create a file path for the original data.
pathxlsx = 'data/cao2020_' + nowstr + '.xlsx'

# %%
urlrq.urlretrieve(url2020, pathxlsx)
# Out:
# ('data/cao2020_20211221_191520.xlsx',
#  <http.client.HTTPMessage at 0x1d44c6501c0>)

# %% [markdown]
# <br>
#
# ### Load Excel Spreadsheet using Pandas
#
# ***

# %% [markdown]
# Similar to the 2021 points, I have given the 2020 points the variable name df2020 and will load the origional data to this dataframe for analysis.

# %%
# Download and break down the excel spreadsheet.
df2020 = pd.read_excel(url2020, skiprows=10)

# %%
df2020
# Out:
#                        CATEGORY (i.e.ISCED description)  \
# 0                           Business and administration
# 1                         Humanities (except languages)
# 2                                                  Arts
# 3                                                  Arts
# 4                                                  Arts
# ...                                                 ...
# 1459                       Manufacturing and processing
# 1460  Information and Communication Technologies (ICTs)
# 1461  Information and Communication Technologies (ICTs)
# 1462                                  Personal services
# 1463                 Engineering and engineering trades
#
#                                            COURSE TITLE COURSE CODE2  \
# 0                                International Business        AC120
# 1                                          Liberal Arts        AC137
# 2      First Year Art & Design (Common Entry,portfolio)        AD101
# ...

# %%
# Spot check a random row.
df2020.iloc[753]
# Out:
# CATEGORY (i.e.ISCED description)          Engineering and engineering trades
# COURSE TITLE                        Road Transport Technology and Management
# COURSE CODE2                                                           LC286
# R1 POINTS                                                                264
# R1 Random *                                                              NaN
# R2 POINTS                                                                NaN
# R2 Random*                                                               NaN
# EOS                                                                      264
# EOS Random *                                                             NaN
# EOS Mid-point                                                            360
# LEVEL                                                                      7
# HEI                                         Limerick Institute of Technology
# ...

# %%
# Spot check the last row.
df2020.iloc[-1]
# Out:
# CATEGORY (i.e.ISCED description)          Engineering and engineering trades
# COURSE TITLE                        Mechanical and Manufacturing Engineering
# COURSE CODE2                                                           WD230
# R1 POINTS                                                                253
# R1 Random *                                                              NaN
# R2 POINTS                                                                NaN
# R2 Random*                                                               NaN
# EOS                                                                      253
# EOS Random *                                                             NaN
# EOS Mid-point                                                            369
# LEVEL                                                                      8
# HEI                                        Waterford Institute of Technology
# ...

# %% [markdown]
# <br>
#
# We can see from the round 1 and 2 columns in df2020 that there are more '*' and '#' characters. However, there also seems to be a '+' sign and letters in the points columns.

# %% [markdown]
# Therefore, I must use the pandas replace function again along with regular expressions to remove any '*', '#' or '+' symbols. And I must also replace any 3 capital letters or any 6 lower case letters that also appear in these columns. This can be seen in the below code cell.
#
# <br>

# %%
# Replace *, # and + characters for 2020 r1 and r2. 
df2020['R1 POINTS'] = df2020['R1 POINTS'].replace('\*', '', regex=True)
df2020['R1 POINTS'] = df2020['R1 POINTS'].replace('\#', '', regex=True)
df2020['R1 POINTS'] = df2020['R1 POINTS'].replace('\+', '', regex=True)
df2020['R1 POINTS'] = df2020['R1 POINTS'].replace('[A-Z]{3}', '', regex=True)
df2020['R1 POINTS'] = df2020['R1 POINTS'].replace('[a-z]{6}', '', regex=True)
df2020['R2 POINTS'] = df2020['R2 POINTS'].replace('\*', '', regex=True)
df2020['R2 POINTS'] = df2020['R2 POINTS'].replace('\#', '', regex=True)
df2020['R2 POINTS'] = df2020['R2 POINTS'].replace('\+', '', regex=True)
df2020['R2 POINTS'] = df2020['R2 POINTS'].replace('[A-Z]{3}', '', regex=True)
df2020['R2 POINTS'] = df2020['R2 POINTS'].replace('[a-z]{6}', '', regex=True)

# %%
# Check if it worked.
df2020
# Out:
#                        CATEGORY (i.e.ISCED description)  \
# 0                           Business and administration
# 1                         Humanities (except languages)
# 2                                                  Arts
# 3                                                  Arts
# 4                                                  Arts
# ...                                                 ...
# 1459                       Manufacturing and processing
# 1460  Information and Communication Technologies (ICTs)
# 1461  Information and Communication Technologies (ICTs)
# 1462                                  Personal services
# 1463                 Engineering and engineering trades
#
#                                            COURSE TITLE COURSE CODE2  \
# 0                                International Business        AC120
# 1                                          Liberal Arts        AC137
# 2      First Year Art & Design (Common Entry,portfolio)        AD101
# ...

# %% [markdown]
# <br>
#
# Now that the symbols have been removed I will use the [pandas.to.csv](https://www.geeksforgeeks.org/python-pandas-series-to_csv/) method which is a useful function that writes a varibale to a csv file using commas to seperate the values. In this case we are writing the 2020 dataframe to the data folder using the time stamp again. Now the 2020 points are ready for analysis.

# %%
# Create a file path for the pandas dataframe.
path2020 = 'data/cao2020_' + nowstr + '.csv'

# %%
# Save new df to data folder in repo.
df2020.to_csv(path2020)

# %% [markdown]
#  <br>
#
# # 2019 CAO Points
#
# http://www.cao.ie/index.php?page=points&p=2019
#
# ***

# %% [markdown]
# This section converts the 2019 CAO points from a pdf file into a pandas dataframe.

# %% [markdown]
# ### Steps for conversion:
#
# 1.  Download original pdf file from the link above.
# 2.  Open original pdf file in Microsoft Word.
# 3.  Save Microsoft Word's converted PDF in docx format.
# 4.  Re-save Word document for editing.
# 5.  Delete headers and footers.
# 6.  Delete preamble on page 1.
# 7.  Select all and copy.
# 8.  Paste into [Visual Studio Code](https://www.videostudiopro.com/en/?link=wm).
# 9.  Remove HEI name lines and any black lines.
# 10. Change column heading "COURSE AND INSTITUTION" to "Course".
# 11. Change backticks to apostrophes.
# 12. Replace double tab charater on line 28 with just a single tab.
# 13. Delete tabs at end of lines 604, 670, 700, 701, 793, and 830.
# 14. Finally save as a csv file in the data folder of this repository.
#
# <br>

# %% [markdown]
# Now this csv file is ready to be loaded into a pandas dataframe named df2019.

# %%
df2019 = pd.read_csv('data/cao2019_20211103_202410_edited.csv', sep='\t')

# %%
df2019
# Out:
#     Course Code                                             Course   EOS  Mid
# 0         AL801    Software Design with Virtual Reality and Gaming   304  328
# 1         AL802               Software Design with Cloud Computing   301  306
# 2         AL803  Software Design with Mobile Apps and Connected...   309  337
# 3         AL805        Network Management and Cloud Infrastructure   329  442
# 4         AL810                                 Quantity Surveying   307  349
# ..          ...                                                ...   ...  ...
# 925       WD200                                     Arts (options)  221   296
# 926       WD210                       Software Systems Development  271   329
# 927       WD211                                 Creative Computing  275   322
# 928       WD212                    Recreation and Sport Management  274   311
# 929       WD230           Mechanical and Manufacturing Engineering  273   348
#
# [930 rows x 4 columns]

# %% [markdown]
# Again, after opening the 2019 csv file I can see more '*' and '#' characters. Once again I will use the pandas replace function so that only the actual points are left in the file. Otherwise, this will have an impact on my analysis.

# %%
# Replace * and # characters for 2019 eos and mid. 
df2019['EOS'] = df2019['EOS'].replace('\*', '', regex=True)
df2019['EOS'] = df2019['EOS'].replace('\#', '', regex=True)
df2019['Mid'] = df2019['Mid'].replace('\*', '', regex=True)
df2019['Mid'] = df2019['Mid'].replace('\#', '', regex=True)

# %%
df2019
# Out:
#     Course Code                                             Course   EOS  Mid
# 0         AL801    Software Design with Virtual Reality and Gaming   304  328
# 1         AL802               Software Design with Cloud Computing   301  306
# 2         AL803  Software Design with Mobile Apps and Connected...   309  337
# 3         AL805        Network Management and Cloud Infrastructure   329  442
# 4         AL810                                 Quantity Surveying   307  349
# ..          ...                                                ...   ...  ...
# 925       WD200                                     Arts (options)  221   296
# 926       WD210                       Software Systems Development  271   329
# 927       WD211                                 Creative Computing  275   322
# 928       WD212                    Recreation and Sport Management  274   311
# 929       WD230           Mechanical and Manufacturing Engineering  273   348
#
# [930 rows x 4 columns]

# %% [markdown]
# <br>
#
# At first sight we can see that the 2019 dataframe doesn't contain round 1 or round 2 points like 2020 or 2021 files do. There are two points columns
#
# - EOS means end of season points.
#
#
# - MID means mid points a student had who got accepted to the course.
#
#
# This is something that will need to be considered in the analysis.

# %%
# Create a file path for the pandas dataframe.
path2019 = 'data/cao2019_' + nowstr + '.csv'

# %%
# Save new df to data folder in repo.
df2019.to_csv(path2019)

# %% [markdown]
# <br>
#
# ***
#
# <br>

# %% [markdown]
# # Concat
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html
#
# ***

# %% [markdown]
# This section will take the 2021, 2021 and 2019 courses, link and join them together into one dataframe for analysis.

# %% [markdown]
# ### Creating column headings
#
# First step is to create a new dataframe for 2021 points with two headings.

# %%
# Creating a new variable for 2021.
courses2021 = df2021[['code', 'title']]
courses2021
# Out:
#       code                                              title
# 0    AL801     Software Design for Virtual Reality and Gaming
# 1    AL802  Software Design in Artificial Intelligence for...
# 2    AL803  Software Design for Mobile Apps and Connected ...
# 3    AL805    Computer Engineering for Network Infrastructure
# 4    AL810                                 Quantity Surveying
# ..     ...                                                ...
# 944  WD211                                 Creative Computing
# 945  WD212                    Recreation and Sport Management
# 946  WD230           Mechanical and Manufacturing Engineering
# 947  WD231                 Early Childhood Care and Education
# 948  WD232                       Business Information Systems
#
# [949 rows x 2 columns]

# %% [markdown]
# Next step is to create a new dataframe for 2020 and 2019 points with the same two headings as 2021.

# %%
# Create new variable for 2020.
courses2020 = df2020[['COURSE CODE2','COURSE TITLE']]
# Set column headings to be the same as 2021.
courses2020.columns = ['code', 'title']
courses2020
# Out:
#        code                                              title
# 0     AC120                             International Business
# 1     AC137                                       Liberal Arts
# 2     AD101   First Year Art & Design (Common Entry,portfolio)
# 3     AD102  Graphic Design and Moving Image Design (portfo...
# 4     AD103  Textile & Surface Design and Jewellery & Objec...
# ...     ...                                                ...
# 1459  WD208                          Manufacturing Engineering
# 1460  WD210                       Software Systems Development
# 1461  WD211                                 Creative Computing
# 1462  WD212                    Recreation and Sport Management
# 1463  WD230           Mechanical and Manufacturing Engineering
#
# [1464 rows x 2 columns]

# %%
# Create new variable for 2019.
courses2019 = df2019[['Course Code','Course']]
# Set column headings to be the same as 2021.
courses2019.columns = ['code', 'title']
courses2019
# Out:
#       code                                              title
# 0    AL801    Software Design with Virtual Reality and Gaming
# 1    AL802               Software Design with Cloud Computing
# 2    AL803  Software Design with Mobile Apps and Connected...
# 3    AL805        Network Management and Cloud Infrastructure
# 4    AL810                                 Quantity Surveying
# ..     ...                                                ...
# 925  WD200                                     Arts (options)
# 926  WD210                       Software Systems Development
# 927  WD211                                 Creative Computing
# 928  WD212                    Recreation and Sport Management
# 929  WD230           Mechanical and Manufacturing Engineering
#
# [930 rows x 2 columns]

# %% [markdown]
# ### Concat 2021, 2021 and 2019
#
# Now the next step is to concatenate these varibales. This is done using the pandas function [concat](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html). To put it simply, this will take the 2020 and 2019 points and put them on top of the 2021 points. I am using the ignore index parameter for this function as pandas automatically gives an index on it's dataframes and it allows for clean lines when sorting for duplicates.

# %% [markdown]
# ### Sort by course code
#
# Pandas has another useful function called [sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html) which does exactly that. In the cell below I am sorting the code values in order to find any duplicates in the concatenated dataframe.

# %%
# Concat two variables ignoring the index. 
allcourses = pd.concat([courses2021, courses2020, courses2019], ignore_index=True)
allcourses
# Out:
#        code                                              title
# 0     AL801     Software Design for Virtual Reality and Gaming
# 1     AL802  Software Design in Artificial Intelligence for...
# 2     AL803  Software Design for Mobile Apps and Connected ...
# 3     AL805    Computer Engineering for Network Infrastructure
# 4     AL810                                 Quantity Surveying
# ...     ...                                                ...
# 3338  WD200                                     Arts (options)
# 3339  WD210                       Software Systems Development
# 3340  WD211                                 Creative Computing
# 3341  WD212                    Recreation and Sport Management
# 3342  WD230           Mechanical and Manufacturing Engineering
#
# [3343 rows x 2 columns]

# %%
allcourses.sort_values('code')
# Out:
#        code                                     title
# 175   AC120                    International Business
# 949   AC120                    International Business
# 2581  AC120                    International Business
# 950   AC137                              Liberal Arts
# 2582  AC137                              Liberal Arts
# ...     ...                                       ...
# 2412  WD230  Mechanical and Manufacturing Engineering
# 946   WD230  Mechanical and Manufacturing Engineering
# 3342  WD230  Mechanical and Manufacturing Engineering
# 947   WD231        Early Childhood Care and Education
# 948   WD232              Business Information Systems
#
# [3343 rows x 2 columns]

# %% [markdown]
# Here I use the pandas function [loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) to check display the duplicate course on two different index'.

# %%
allcourses.loc[175]['title']
# Out:
# 'International Business'

# %%
allcourses.loc[949]['title']
# Out:
# 'International Business'

# %% [markdown]
# ### Find and remove duplicates
#
# Pandas has yet another useful function called [duplicated](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html). This function sieves through the selected dataframe and returns any duplicated rows. Furthermore, pandas has another function which will remove any duplicated rows. This is called [drop_duplicates](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html#pandas.DataFrame.drop_duplicates).

# %%
# Finds all extra copies of duplicated rows.
allcourses[allcourses.duplicated()]
# Out:
#        code                                              title
# 949   AC120                             International Business
# 950   AC137                                       Liberal Arts
# 952   AD102  Graphic Design and Moving Image Design (portfo...
# 955   AD204                               Fine Art (portfolio)
# 956   AD211                         Fashion Design (portfolio)
# ...     ...                                                ...
# 3338  WD200                                     Arts (options)
# 3339  WD210                       Software Systems Development
# 3340  WD211                                 Creative Computing
# 3341  WD212                    Recreation and Sport Management
# 3342  WD230           Mechanical and Manufacturing Engineering
#
# [1392 rows x 2 columns]

# %%
# Returns a copy of the data frame with duplciates removed.
allcourses.drop_duplicates()
# Out:
#        code                                              title
# 0     AL801     Software Design for Virtual Reality and Gaming
# 1     AL802  Software Design in Artificial Intelligence for...
# 2     AL803  Software Design for Mobile Apps and Connected ...
# 3     AL805    Computer Engineering for Network Infrastructure
# 4     AL810                                 Quantity Surveying
# ...     ...                                                ...
# 3281  TL801         Animation Visual Effects and Motion Design
# 3282  TL802                            TV, Radio and New Media
# 3283  TL803                                   Music Technology
# 3286  TL812                       Computing with Digital Media
# 3324  WD148                                  Tourism Marketing
#
# [1951 rows x 2 columns]

# %% [markdown]
# ### Find and remove duplicates using course code
#
# An important note here is that the 2021 and 2020 formats might differ. Therefore, it is fair to say that some course titles might have been written using differnet syntax and may not have been picked up in the previous arguments. However, the course code seems to have the exact same format.
#
#
# Luckily, there is a way to check and remove duplicates based on the course code alone. This is done by passing the subset parameter which will only consider the data in the selction column, find duplicates and remove them.

# %%
# Finds duplicates in code column.
allcourses[allcourses.duplicated(subset=['code'])]
# Out:
#        code                                              title
# 949   AC120                             International Business
# 950   AC137                                       Liberal Arts
# 951   AD101   First Year Art & Design (Common Entry,portfolio)
# 952   AD102  Graphic Design and Moving Image Design (portfo...
# 953   AD103  Textile & Surface Design and Jewellery & Objec...
# ...     ...                                                ...
# 3338  WD200                                     Arts (options)
# 3339  WD210                       Software Systems Development
# 3340  WD211                                 Creative Computing
# 3341  WD212                    Recreation and Sport Management
# 3342  WD230           Mechanical and Manufacturing Engineering
#
# [1692 rows x 2 columns]

# %% [markdown]
# <br>
#
# In the function below, I pass in two other parameters.
#
# - inplace=True will drop the duplicates making the change permament.
#
#
# - ignore_index=True will ignore the index' of the origional arrays and basically re-sets the index on the new dataframe.

# %%
# Returns new dataframe with duplciates removed - based only on code.
allcourses.drop_duplicates(subset=['code'], inplace=True, ignore_index=True)

# %%
allcourses
# Out:
#        code                                              title
# 0     AL801     Software Design for Virtual Reality and Gaming
# 1     AL802  Software Design in Artificial Intelligence for...
# 2     AL803  Software Design for Mobile Apps and Connected ...
# 3     AL805    Computer Engineering for Network Infrastructure
# 4     AL810                                 Quantity Surveying
# ...     ...                                                ...
# 1646  SG441                              Environmental Science
# 1647  SG446                                Applied Archaeology
# 1648  TL803                                   Music Technology
# 1649  TL812                       Computing with Digital Media
# 1650  WD148                                  Tourism Marketing
#
# [1651 rows x 2 columns]

# %% [markdown]
# Now the variable allcourses is a dataframe with the combined 2021, 2020 and 2019 courses code and titles.

# %% [markdown]
# <br>
#
# # Join to points
#
# ***

# %% [markdown]
# Now that the 2021 and 2020 courses have been combined, the next step is to join the points to the datframe.

# %% [markdown]
# ### Setting index and columns for df2021
#
# Instead of having dataframes with different index' it is a better idea to set the course code as the index. This is done by using the function [set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html) which permanently makes the code column the index of the dataframe.

# %% [markdown]
# Now that the index is set we need to add the columns to the 2021 dataframe. This is done by using the [columns](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html) function. When setting the column headings it is important to use the heading names as they were in the origional dataframe.

# %%
# Set index and columns for 2021. 
df2021.set_index('code', inplace=True)
df2021.columns = ['title', 'points_r1_2021', 'points_r2_2021']
df2021
# Out:
#                                                    title points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming            300
# AL802  Software Design in Artificial Intelligence for...            313
# AL803  Software Design for Mobile Apps and Connected ...            350
# AL805    Computer Engineering for Network Infrastructure            321
# AL810                                 Quantity Surveying            328
# ...                                                  ...            ...
# WD211                                 Creative Computing            270
# WD212                    Recreation and Sport Management            262
# WD230           Mechanical and Manufacturing Engineering            230
# WD231                 Early Childhood Care and Education            266
# WD232                       Business Information Systems            261
#
#       points_r2_2021
# code
# AL801            NaN
# AL802            NaN
# AL803            NaN
# ...

# %% [markdown]
# <br>
#
# ### Join 2021 points to allcourses dataframe
#
# Next we join the 2021 points to the new dataframe containing the course codes from both 2021 and 2020. This is done by using the [join](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html) function and selecting just the round 1 points.

# %%
# Set the index again.
allcourses.set_index('code', inplace=True)
# Join the df data to column. 
allcourses = allcourses.join(df2021[['points_r1_2021']])
allcourses
# Out:
#                                                    title points_r1_2021
# code
# AL801     Software Design for Virtual Reality and Gaming            300
# AL802  Software Design in Artificial Intelligence for...            313
# AL803  Software Design for Mobile Apps and Connected ...            350
# AL805    Computer Engineering for Network Infrastructure            321
# AL810                                 Quantity Surveying            328
# ...                                                  ...            ...
# SG441                              Environmental Science            NaN
# SG446                                Applied Archaeology            NaN
# TL803                                   Music Technology            NaN
# TL812                       Computing with Digital Media            NaN
# WD148                                  Tourism Marketing            NaN
#
# [1651 rows x 2 columns]

# %% [markdown]
# ### Extract 2020 round 1 points
#
# Now that the allcourses dataframe contains the 2021 points we need to add the 2020 points as well. This is done using the same format as above. First we need to extract the round 1 points and then set the column name to the same syntax as the previous one.

# %%
# Set 2020 round 1 points to new variable.
df2020_r1 = df2020[['COURSE CODE2', 'R1 POINTS']]
df2020_r1.columns = ['code', 'points_r1_2020']
df2020_r1
# Out:
#        code points_r1_2020
# 0     AC120            209
# 1     AC137            252
# 2     AD101
# 3     AD102
# 4     AD103
# ...     ...            ...
# 1459  WD208            188
# 1460  WD210            279
# 1461  WD211            271
# 1462  WD212            270
# 1463  WD230            253
#
# [1464 rows x 2 columns]

# %% [markdown]
# ### Setting index for 2020 round 1 points
#
# Similar to the 2021 dataframe, the index needs to be set to the course code again so that the correct 2020 points are assigned to the correct course in the new dataframe.

# %%
# Set the index to the code column.
df2020_r1.set_index('code', inplace=True)
df2020_r1
# Out:
#       points_r1_2020
# code
# AC120            209
# AC137            252
# AD101
# AD102
# AD103
# ...              ...
# WD208            188
# WD210            279
# WD211            271
# WD212            270
# WD230            253
#
# [1464 rows x 1 columns]

# %% [markdown]
# ### Join 2020 round 1 points to allcourses
#
# The next step is to use the pandas joing function again to add the 2020 round 1 points to the allcourses dataframe which already contains the 2021 points.

# %%
# Join 2020 R1 points to allcourses.
allcourses = allcourses.join(df2020_r1)
allcourses
# Out:
#                                                    title points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming            300
# AL802  Software Design in Artificial Intelligence for...            313
# AL803  Software Design for Mobile Apps and Connected ...            350
# AL805    Computer Engineering for Network Infrastructure            321
# AL810                                 Quantity Surveying            328
# ...                                                  ...            ...
# SG441                              Environmental Science            NaN
# SG446                                Applied Archaeology            NaN
# TL803                                   Music Technology            NaN
# TL812                       Computing with Digital Media            NaN
# WD148                                  Tourism Marketing            NaN
#
#       points_r1_2020
# code
# AL801            303
# AL802            332
# AL803            337
# ...

# %% [markdown]
# ### Extract 2019 EOS points
#
# As the origional 2019 CAO PDF only contains end of season figures, we will use this to compare with 2021 and 2020.

# %%
# Set 2019 eos points to new variable.
df2019_r1 = df2019[['Course Code', 'EOS']]
df2019_r1.columns = ['code', 'points_r1_2019']
df2019_r1
# Out:
#       code points_r1_2019
# 0    AL801            304
# 1    AL802            301
# 2    AL803            309
# 3    AL805            329
# 4    AL810            307
# ..     ...            ...
# 925  WD200           221
# 926  WD210           271
# 927  WD211           275
# 928  WD212           274
# 929  WD230           273
#
# [930 rows x 2 columns]

# %% [markdown]
# ### Setting index for 2019 points
#
# I need to set the index to the code code and I did with the 2021 and 2020 points.

# %%
# Set the index to the code column.
df2019_r1.set_index('code', inplace=True)
df2019_r1
# Out:
#       points_r1_2019
# code
# AL801            304
# AL802            301
# AL803            309
# AL805            329
# AL810            307
# ...              ...
# WD200           221
# WD210           271
# WD211           275
# WD212           274
# WD230           273
#
# [930 rows x 1 columns]

# %%
df2019.dtypes
# Out:
# Course Code    object
# Course         object
# EOS            object
# Mid            object
# dtype: object

# %% [markdown]
# ### Join 2019 to allcourses
#
# The final step here is to use pandas to join the 2019points to the allcourses dataframe.

# %%
# Join 2019 points to allcourses.
allcourses = allcourses.join(df2019_r1)
allcourses
# Out:
#                                                    title points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming            300
# AL802  Software Design in Artificial Intelligence for...            313
# AL803  Software Design for Mobile Apps and Connected ...            350
# AL805    Computer Engineering for Network Infrastructure            321
# AL810                                 Quantity Surveying            328
# ...                                                  ...            ...
# SG441                              Environmental Science            NaN
# SG446                                Applied Archaeology            NaN
# TL803                                   Music Technology            NaN
# TL812                       Computing with Digital Media            NaN
# WD148                                  Tourism Marketing            NaN
#
#       points_r1_2020 points_r1_2019
# code
# AL801            303            304
# ...

# %% [markdown]
# As we can see the allcourses dataframe conatins 4 columns; title, points_r1_2021, points_r1_2020 and points_r1_2019.

# %%
# Create a file path for the pandas dataframe.
path_all = 'data/cao_allcourses_' + nowstr + '.csv'

# %%
# Save new df to data folder in repo.
allcourses.to_csv(path_all)

# %% [markdown]
# <br>
#
# # Analysis
#
# ***

# %% [markdown]
# ## Calling the dataframe
#
# Reading in a specific csv file here so that the data used in my analysis does not change over time and remains relevent to the current information in this file.

# %%
# Read in csv, set columns and index and call as df from now on. 
data = pd.read_csv('data/cao_allcourses_20211210_115005.csv')
df = pd.DataFrame(data, columns=['code', 'title','points_r1_2021','points_r1_2020','points_r1_2019'])
df.set_index('code', inplace=True)
df
# Out:
#                                                    title  points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming           300.0
# AL802  Software Design in Artificial Intelligence for...           313.0
# AL803  Software Design for Mobile Apps and Connected ...           350.0
# AL805    Computer Engineering for Network Infrastructure           321.0
# AL810                                 Quantity Surveying           328.0
# ...                                                  ...             ...
# SG441                              Environmental Science             NaN
# SG446                                Applied Archaeology             NaN
# TL803                                   Music Technology             NaN
# TL812                       Computing with Digital Media             NaN
# WD148                                  Tourism Marketing             NaN
#
#        points_r1_2020 points_r1_2019
# code
# AL801           303.0            NaN
# ...

# %% [markdown]
# ### dtypes
#
# As I began plotting the data from this dataset it became apparent that there were still issues with the data from 2019. As I struggled to plot the data alongside the other years I found an interesting blog post from someone who had a similar issue over four years ago. The suggestion found in this [blog](https://stackoverflow.com/questions/44530047/why-is-my-numeric-data-being-treated-as-an-object) was that when converting from a PDF to a CSV file, the data may have lost it's data type. I decided to test this theory on my dataset by using the [pandas DataFrame dtype](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html) function which returns the data type of each columns.

# %% [markdown]
# As we can see below, the points_r1_2019 column is an object and not a float like the other years. This is the reason I am having issues in my analysis.

# %%
# Note data type of 2019. 
df.dtypes
# Out:
# title              object
# points_r1_2021    float64
# points_r1_2020    float64
# points_r1_2019     object
# dtype: object

# %% [markdown]
# The blog where I initally discovered what might be happening suggested using the [pandas to numeric](https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html) funciton. You pass in the argumnet to be converted which in this case is the column `points_r1_2019`. Then it returns the data as a float or integer depending on the origional argument. Another important note is that I am using the errors paramenter in this function as some rows within this column don't hold any points as that course may not have been offered that year or maybe there was a portfolio or interview required instead. Therefore, by selecting coerce it will set any invalid rows to [NaN](https://towardsdatascience.com/5-methods-to-check-for-nan-values-in-in-python-3f21ddd17eed#:~:text=How%20to%20check%20if%20a%20single%20value%20is%20NaN%20in%20python.&text=NaN%20stands%20for%20Not%20A,major%20problems%20in%20Data%20Analysis.) which means it's not a number.

# %%
# Converting column to numeric values. 
df['points_r1_2019'] = pd.to_numeric(df['points_r1_2019'], errors='coerce')

# %% [markdown]
# Now it's time to test the theory by calling on dtypes again. As we can see, the points_r1_2019 column is no longer considered an object but now a float which has numeric value and can be analysed and plotted.

# %%
# Fixed! Now all three columns are numeric values. 
df.dtypes
# Out:
# title              object
# points_r1_2021    float64
# points_r1_2020    float64
# points_r1_2019    float64
# dtype: object

# %% [markdown]
# ## Pandas functions
#
# Pandas has a huge library of functions that can be used when analysising dataframes. Some of these include the following:

# %% [markdown]
# ### Head
#
# This [funciton](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) is used on a pandas dataframe to return the first 5 rows. However, you could select any number of rows starting at the top of the dataframe that you wish to select. This function only gives us a brief insight into the beginning of this dataframe. However, we can already see from below that the very frist course "Software Design for Virtual Reality and Gaming" must be a newly run course as it was not offered in 2019.

# %%
# Default returns first 5 rows of df.  
df.head()
# Out:
#                                                    title  points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming           300.0
# AL802  Software Design in Artificial Intelligence for...           313.0
# AL803  Software Design for Mobile Apps and Connected ...           350.0
# AL805    Computer Engineering for Network Infrastructure           321.0
# AL810                                 Quantity Surveying           328.0
#
#        points_r1_2020  points_r1_2019
# code
# AL801           303.0             NaN
# AL802           332.0           301.0
# AL803           337.0           309.0
# AL805           333.0           329.0
# AL810           319.0             NaN

# %%
# Or you can specify a number. 
df.head(9)
# Out:
#                                                    title  points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming           300.0
# AL802  Software Design in Artificial Intelligence for...           313.0
# AL803  Software Design for Mobile Apps and Connected ...           350.0
# AL805    Computer Engineering for Network Infrastructure           321.0
# AL810                                 Quantity Surveying           328.0
# AL811                                  Civil Engineering             NaN
# AL820                 Mechanical and Polymer Engineering           327.0
# AL830                                    General Nursing           451.0
# AL832                              Mental Health Nursing           440.0
#
#        points_r1_2020  points_r1_2019
# code
# AL801           303.0             NaN
# AL802           332.0           301.0
# AL803           337.0           309.0
# AL805           333.0           329.0
# ...

# %% [markdown]
# ### Tail
#
# Similar to the head function, the [tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html) will return the last 5 rows from the bottom of the selection dataframe. Again, you can choose a specific number if desired. Interestingly, we can see from the tail function used below that these courses which were offered in 2019 were not put forward in 2020 or 2021.

# %%
# Default returns last 5 rows of df. 
df.tail()
# Out:
#                               title  points_r1_2021  points_r1_2020  \
# code
# SG441         Environmental Science             NaN             NaN
# SG446           Applied Archaeology             NaN             NaN
# TL803              Music Technology             NaN             NaN
# TL812  Computing with Digital Media             NaN             NaN
# WD148             Tourism Marketing             NaN             NaN
#
#        points_r1_2019
# code
# SG441           297.0
# SG446           289.0
# TL803           264.0
# TL812           369.0
# WD148           269.0

# %%
# Or select a number. 
df.tail(3)
# Out:
#                               title  points_r1_2021  points_r1_2020  \
# code
# TL803              Music Technology             NaN             NaN
# TL812  Computing with Digital Media             NaN             NaN
# WD148             Tourism Marketing             NaN             NaN
#
#        points_r1_2019
# code
# TL803           264.0
# TL812           369.0
# WD148           269.0

# %% [markdown]
# ### Shape
#
# This [function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html) returns the dimensionality of the selected dataframe. As we can see below, this dataframe has 1652 rows and 4 columns.

# %%
# returns the shape of df. 
df.shape
# Out:
# (1652, 4)

# %% [markdown]
# ### Size
#
# This [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.size.html) can either return the number of rows if used on a pandas series, or if used on a dataframe as I have done below, it returns the number of rows multiplied by the numebr of columns.
#
# This is true if you take the information from the shape function above:
#
# 1652 * 4 = 6608

# %%
# Returns rows times columns of df. 
df.size
# Out:
# 6608

# %% [markdown]
# ### Describe
#
# [Describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html) is a useful funciton in pandas. It returns a table with general descriptive statictics. All of these functions can be individually called upon in pandas, however, the describe function returns a quick table showing these statictics together in one table. This includes the count of rows, the mean, standard deviation, the minimun value, the maximun value and the 25th, 50th, and 75th percentiles of the dataframe.
#
#
# This function has produced some intriguing data which I will analyse below.

# %%
# Describes general statistics. 
df.describe()
# Out:
#        points_r1_2021  points_r1_2020  points_r1_2019
# count      923.000000     1394.000000      891.000000
# mean       407.666306      350.995696      370.209877
# std        128.706224      134.433752      115.551874
# min         57.000000       55.000000       55.000000
# 25%        303.000000      252.250000      290.000000
# 50%        391.000000      316.500000      347.000000
# 75%        499.000000      433.000000      434.500000
# max       1028.000000     1088.000000      933.000000

# %% [markdown]
# #### [Count](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html)
# In this table we can see that in 2020 there were 1394 courses offered which is 471 more than 2021 and 503 more than 2019. This would suggest a sudden rise in courses and and then a sudden drop. Interestingly, this coincedies with the current [coronovirus pandemic](https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_Ireland) which first began in Ireland in February 2020. The [CAO's deadline](https://www.cao.ie/#:~:text=Closing%20Date%20for%20Applications%20is%20the%201st%20February%20at%2017%3A00.) for course applications is normally February 1st every year. This would suggest a link as to why there were more courses put forward in 2020 as it would have been prior to the pandemic and less in 2021 as the pandemic is currently ongoing.

# %%
# Returns the count. 
df.count()
# Out:
# title             1651
# points_r1_2021     923
# points_r1_2020    1394
# points_r1_2019     891
# dtype: int64

# %% [markdown]
# #### [Mean](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html)
#
# This function returns the average values of each column in the dataframe. We can see from this function that the median points required was greater in 2021 than in 2020 and 2019. There was a drop in 2020 and then an increase. However, there are other factors to consider. We already discovered from the count function that there were more courses on offer in 2020 than in 2021 or 2019. The [mean](https://www.cuemath.com/data/mean/) is calculated by adding all the points in the column togehter and dividing by the number of rows in that column. Therefore, this could explain why there would be a lower mean value in 2020.

# %%
# Returns the mean of each column. 
df.mean()
# Out:
# points_r1_2021    407.666306
# points_r1_2020    350.995696
# points_r1_2019    370.209877
# dtype: float64

# %% [markdown]
# #### [Standard deviation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html)
#
# This function is used to retrieve the amount of variation of a set of values. There are [four steps](https://www.mathsisfun.com/data/standard-deviation-formulas.html) to calculating the standard deviation.
#
# 1. Calculate the mean.
# 2. Subtract the mean from each number and square the result.
# 3. Calculate the mean again.
# 4. Calculate the square root and that gives the standard deviation.
#
# Thankfully this function does this calculation with just one call. We can see from the below calculation that the standard deviation is lower in 2019 than in the other years. This is following a similar pattern to the count of the dataframe. There were more courses offered in 2020 which has the highest standard deviation. 2021 offered fewer than 2020 but more than 2019 which would explain why the standard deviation is slightly higher in 2021 than in 2019.

# %%
# Returns the standard deviation. 
df.std()
# Out:
# points_r1_2021    128.706224
# points_r1_2020    134.433752
# points_r1_2019    115.551874
# dtype: float64

# %% [markdown]
# #### [Minimun Values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.min.html?highlight=df%20min)
# In contrast to the change in the amount of courses, the minimun entry points hasn't changed much in the last three years. We can see from the table above that it remained at 55 from 2019 to 2020 and only went up to 57 in 2021.

# %%
# Returns the minimum values. 
df.min()
# Out:
# points_r1_2021    57.0
# points_r1_2020    55.0
# points_r1_2019    55.0
# dtype: float64

# %% [markdown]
# #### [Maximun Values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.max.html)
# However, there was a huge jump in the maximun CAO points required from 2019 to 2020. It went up by 155 points in just one year. Yet the maximum points dropped again by 60 from 2020 to 2021.

# %%
# Returns the maximum values. 
df.max()
# Out:
# points_r1_2021    1028.0
# points_r1_2020    1088.0
# points_r1_2019     933.0
# dtype: float64

# %% [markdown]
# ### Query
#
# This pandas [function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html) uses a boolean expression to query columns in a dataframe. In other words, it returns any instance where the boolean statement is true.
#
# For example, if we query how many course points in 2021 were greater than 2020, we can see there are 623 courses where points were greater than in 2021 than in 2020.

# %%
# Query boolean expression.  
df.query('points_r1_2021 > points_r1_2020')
# Out:
#                                                    title  points_r1_2021  \
# code
# AL803  Software Design for Mobile Apps and Connected ...           350.0
# AL810                                 Quantity Surveying           328.0
# AL820                 Mechanical and Polymer Engineering           327.0
# AL830                                    General Nursing           451.0
# AL832                              Mental Health Nursing           440.0
# ...                                                  ...             ...
# WD163                                         Psychology           456.0
# WD187                                     Social Science           276.0
# WD192                               Social Care Practice           271.0
# WD193                        Marketing and Digital Media           279.0
# WD194                                      Culinary Arts           237.0
#
#        points_r1_2020  points_r1_2019
# code
# AL803           337.0           309.0
# ...

# %% [markdown]
# If we check how many courses had values less in 2021 than 2020, we can see that there were only 187 courses where the points were less value in 2021 than in 2020.

# %%
# Query boolean expression.
df.query('points_r1_2021 < points_r1_2020')
# Out:
#                                                    title  points_r1_2021  \
# code
# AL801     Software Design for Virtual Reality and Gaming           300.0
# AL802  Software Design in Artificial Intelligence for...           313.0
# AL805    Computer Engineering for Network Infrastructure           321.0
# AL840                            Pharmaceutical Sciences           346.0
# AL854    Sport Management (with international placement)           300.0
# ...                                                  ...             ...
# WD186                    Sports Coaching and Performance           261.0
# WD210                       Software Systems Development           260.0
# WD211                                 Creative Computing           270.0
# WD212                    Recreation and Sport Management           262.0
# WD230           Mechanical and Manufacturing Engineering           230.0
#
#        points_r1_2020  points_r1_2019
# code
# AL801           303.0             NaN
# ...

# %% [markdown]
# If we compare 2020 and 2019 we see that there were 176 courses where the points were less in 2020 than in 2019.

# %%
# Query boolean expression.
df.query('points_r1_2020 < points_r1_2019')
# Out:
#                                                    title  points_r1_2021  \
# code
# AL836                       Nutrition and Health Science           346.0
# AL843               Physical Activity and Health Science           306.0
# AL851                                   Business and Law           302.0
# AL855  Hospitality Management (with international pla...           309.0
# AL860                               Social Care Practice           301.0
# ...                                                  ...             ...
# GY126                   Arts (English and Media Studies)             NaN
# LC401                 Early Childhood Education and Care             NaN
# LC613                 Early Childhood Education and Care             NaN
# SG144  Business in International Marketing and Langua...             NaN
# WD149                            Early Childhood Studies             NaN
#
#        points_r1_2020  points_r1_2019
# code
# AL836           334.0           383.0
# ...

# %% [markdown]
# And here we see that 534 course points increased from 2019 to 2020.

# %%
# Query boolean expression.
df.query('points_r1_2020 > points_r1_2019')
# Out:
#                                                    title  points_r1_2021  \
# code
# AL802  Software Design in Artificial Intelligence for...           313.0
# AL803  Software Design for Mobile Apps and Connected ...           350.0
# AL805    Computer Engineering for Network Infrastructure           321.0
# AL830                                    General Nursing           451.0
# AL838                                      Biotechnology           324.0
# ...                                                  ...             ...
# TR017                                   Law and Business             NaN
# TR020                          Law and Political Science             NaN
# TR029                    Political Science and Geography             NaN
# TR082                      Computer Science and Business             NaN
# TR083                        Sociology and Social Policy             NaN
#
#        points_r1_2020  points_r1_2019
# code
# AL802           332.0           301.0
# ...

# %% [markdown]
# We can also use another boolean expression to see which course points were the same in 2021 and 2019.
#
# In the example below, there are 13 courses where there was slight increases in 2020, slight decreases in 2020 or the points remained the same in all 3 years. This shows us that there was a steady intake of students in these 3 years.

# %%
# Query boolean expression.
d = df.query('points_r1_2021 == points_r1_2019')
d
# Out:
#                                            title  points_r1_2021  \
# code
# CW938                          Business with Law           270.0
# CK101                             Arts - 3 years           300.0
# GC200                                   Business           269.0
# NC020                         Marketing Practice           270.0
# GA181                                 Accounting           303.0
# GA682                     Biomedical Engineering           331.0
# GA788                Computing and Digital Media           270.0
# LY208                                        Law           300.0
# LY818                     Science - Common Entry           302.0
# LC225                   Marketing and Management           298.0
# MH402                       Quantitative Finance           476.0
# MH603                     Computational Thinking           520.0
# TL871  Health and Leisure (Degree Award options)           303.0
#
#        points_r1_2020  points_r1_2019
# code
# ...

# %% [markdown]
# Below I have created a simple bar plot to visualise which courses had the same points in 2021 and 2019. From this plot we can clearly see 3 outcomes:
#
#
# 1. CAO points for CK101, LY208, LC225 and MH402 all remained to same for all 3 years.
#
#
# 2. The points for CW938, NC020, GA181, GA788, LY818 and MH603 all had a slight increase in 2020 and then a slight decrease in 2021.
#
#
# 3. Finally, the points for GC200, GA682 and TL871 all decreased 2020 and then increased again in 2021.

# %%
# Bar plot of above query.
ax = d.plot.bar(rot=0)
ax.set_title('Overview of CAO courses that had equal points in 2019 and 2020')
ax.set_xlabel('Points')
ax.set_ylabel('Course Code')
plt.show()

# %% [markdown]
# ### Loc
#
# The [loc function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) is used to retireve a group of rows and columns using a label or boolean array. For example, lets locate the row TR085. This function has returned the title of this course and the points from all 3 years.
#
#
# From this we can see that the points for Business Studies and French in Trinity College went up by 31 points from 2019 to 2020. And they went up by a further 24 points in 2021. The points went up in this particular course by a total of 55 points from 2019 to 2021.

# %%
# Returns loc info.
df.loc['TR085']
# Out:
# title             Business Studies and French
# points_r1_2021                          564.0
# points_r1_2020                          540.0
# points_r1_2019                          509.0
# Name: TR085, dtype: object

# %% [markdown]
# ### Iloc
#
# Similar to the loc function, [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html#pandas.DataFrame.iloc) locates a position based on indexing. There are a number of ways of doing this. For example:
#
#
# 1. First just a simple integer which will locate at a specific position. For example, below I have selected the fifth value which is actually row 6 because [indexing](https://www.datacamp.com/community/tutorials/python-list-index) begins at 0.

# %%
# Locate at position 5 starting at 0. 
df.iloc[5]
# Out:
# title             Civil Engineering
# points_r1_2021                  NaN
# points_r1_2020                320.0
# points_r1_2019                  NaN
# Name: AL811, dtype: object

# %% [markdown]
# 2. Next with a list of integers, For example, postion 5, 20 and 59. This only returns these 3 rows in the dataframe.

# %%
# Locate at the following positions. 
t = df.iloc[[5, 20, 59]]
t
# Out:
#                             title  points_r1_2021  points_r1_2020  \
# code
# AL811           Civil Engineering             NaN           320.0
# AL851            Business and Law           302.0           295.0
# CW808  Media and Public Relations           247.0           251.0
#
#        points_r1_2019
# code
# AL811             NaN
# AL851           301.0
# CW808           248.0

# %% [markdown]
# 3. We can use slicing to select certain positions. For example, from position 10 up until position 14.

# %%
# Return select rows.
df.iloc[10:14]
# Out:
#                                          title  points_r1_2021  \
# code
# AL836             Nutrition and Health Science           346.0
# AL837  Sports Science with Exercise Physiology           357.0
# AL838                            Biotechnology           324.0
# AL839                             Microbiology           325.0
#
#        points_r1_2020  points_r1_2019
# code
# AL836           334.0           383.0
# AL837           351.0           351.0
# AL838           307.0           302.0
# AL839           325.0           322.0

# %% [markdown]
# <br>
#
# ## Plotting
# ***

# %% [markdown]
# ### Horizontal bar plot
#
# A [horizontal bar plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html) displays data with rectangular bars. The lenght of these bars represents the amount of points for each course. The three years are colour coded which can be seen in the below legend. This allows us to visualise and compare the data from all three years.
#
#
# As you can see I have used the iloc function again to select the first ten values. I have selected a small number for comparrison as it is more clear on the plot as there are over 1600 courses in this dataframe. Therefore, it would not be legiable to visualise all this data in one horizontal bar plot.

# %%
# Horizontal bar plot. 
s = df.iloc[:10]

ax = s.plot.barh()
# invert y axis.
ax.invert_yaxis()
ax.set_title('Overview of first ten CAO courses')
ax.set_xlabel('Points')
ax.set_ylabel('Course Code')
plt.show()

# %% [markdown]
# In this barh we can see that AL835 was only offered in 2021. This would suggest it is a newly run course.

# %%
# Returns specific label.
df.loc['AL835']
# Out:
# title             Pharmacology
# points_r1_2021           356.0
# points_r1_2020             NaN
# points_r1_2019             NaN
# Name: AL835, dtype: object

# %% [markdown]
# Similarily, AL811 was run in 2020 but not in 2021 or 2019. This raises the question if this course was succesful or if there was enough demand for it.

# %%
# Return specific label.
df.loc['AL811']
# Out:
# title             Civil Engineering
# points_r1_2021                  NaN
# points_r1_2020                320.0
# points_r1_2019                  NaN
# Name: AL811, dtype: object

# %% [markdown]
# Another interesting statistic is that the points for AL832 mental health nursing remained the same form 2019 to 2020 but increased by 53 points in 2021. This would suggest there is more demand for this course.

# %%
# Return specific label.
df.loc['AL832']
# Out:
# title             Mental Health Nursing
# points_r1_2021                    440.0
# points_r1_2020                    387.0
# points_r1_2019                    387.0
# Name: AL832, dtype: object

# %% [markdown]
# AL803 shows an increase from 2019 to 2020 to 2021. This indicates more of a demand for this course as the required points has increased by 41 points in the last 3 years. It would be interesting to see if the rise continues in 2022.

# %%
# Return specific label.
df.loc['AL803']
# Out:
# title             Software Design for Mobile Apps and Connected ...
# points_r1_2021                                                350.0
# points_r1_2020                                                337.0
# points_r1_2019                                                309.0
# Name: AL803, dtype: object

# %% [markdown]
# ### Line Plot
#
# A [line plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.line.html) uses the values in the dataframe as coordinates for the lines.
#
#
# I have once again used the iloc function to select 5 courses from row 55 to row 60. This will allow a clear view for analysis. I have also select a marker for the exact point of each value in this range.

# %%
# Line plot. 
r = df.iloc[55:60]

ax = r.plot.line(marker='o')
ax.set_xlabel('Course Code')
ax.set_ylabel('Points')
ax.set_title('Overview of CAO courses from row 55 to 60')
plt.show()

# %% [markdown]
# We can see here that the points for CW728 Product Design Innovation were highest in 2019 at 286 points. There was then a drop of 34 points in 2020 and a further 6 points in 2021. That is a total drop of 40 points in the last 3 years. This suggest there is less of a demand for this course.

# %%
# Return specific label.
df.loc['CW728']
# Out:
# title             Product Design Innovation
# points_r1_2021                        246.0
# points_r1_2020                        252.0
# points_r1_2019                        286.0
# Name: CW728, dtype: object

# %% [markdown]
# From this plot there seems to be a significant differnce in points for CW758 Professional Social Care Practice from 2019 to 2021. There was an increase by 46 points from 2019 to 2020 and a further increase of 24 points in 2021. That is a total of 70 points in just 3 years. This indicates a higher demand.

# %%
# Return specific label.
df.loc['CW758']
# Out:
# title             Professional Social Care Practice
# points_r1_2021                                360.0
# points_r1_2020                                336.0
# points_r1_2019                                290.0
# Name: CW758, dtype: object

# %% [markdown]
# In contrast to these two courses, CW808 Media and Public Relations has almost stayed the same in all 3 years. The points only went up by 3 in 2020 and came down by 4 in 2021. This shows a steady intake of students each year.

# %%
# Return specific label.
df.loc['CW808']
# Out:
# title             Media and Public Relations
# points_r1_2021                         247.0
# points_r1_2020                         251.0
# points_r1_2019                         248.0
# Name: CW808, dtype: object

# %% [markdown]
# ### Bar Plot
#
# A [barplot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html) is similar to the horizontal bar plot. The different is it displays the rectangular bars vertically. Again, I have chosen 10 rows from this dataframe to display on this plot.

# %%
# Create bar plot.
b = df.iloc[300:310]

ax = b.plot.bar(rot=0)
ax.set_title('Overview of CAO points from row 300 to 310')
ax.set_xlabel('Points')
ax.set_ylabel('Course Code')
plt.show()

# %% [markdown]
# As we can see for the first course GC402 Business HRM, the points increased by 47 points from 2019 to 2020. Furthermore, this course didn't run at all in 2021. It is difficult to know if this was just for 2021 or if the course was terminated completely.

# %%
# Return specific label.
df.loc['GC402']
# Out:
# title             Business (HRM)
# points_r1_2021               NaN
# points_r1_2020             264.0
# points_r1_2019             217.0
# Name: GC402, dtype: object

# %% [markdown]
# Interestingly, this plot has indicated that two courses GC462 Design Communication and BY001 Business only ran in 2021. This suggests that these were developed due to a higher demand in these sectors.

# %%
# Return specific label.
df.loc['GC462']
# Out:
# title             Design Communication (portfolio)
# points_r1_2021                               300.0
# points_r1_2020                                 NaN
# points_r1_2019                                 NaN
# Name: GC462, dtype: object

# %%
# Return specific label.
df.loc['BY001']
# Out:
# title             Business
# points_r1_2021       210.0
# points_r1_2020         NaN
# points_r1_2019         NaN
# Name: BY001, dtype: object

# %% [markdown]
# Another interesting statistic is course GC430 Computing Science. There was an increase in points required by 35 from 2019 to 2020. However, in contrast to this there was only a drop of 1 point in 2021. This implies more of a demand in 2019 and a more steady demand in 2020. Will this course points remain to same next year, drop or increase?

# %%
# Return specific label.
df.loc['GC430']
# Out:
# title             Computing Science
# points_r1_2021                251.0
# points_r1_2020                252.0
# points_r1_2019                217.0
# Name: GC430, dtype: object

# %% [markdown]
# # Conclusion
# ***

# %% [markdown]
# This notebook describes how to convert data from http, excel and PDF format into csv files. It then takes us through the steps into loading all three csv files into one dataframe that is then used for analysis. In order to compare data it is important to make sure origional sourcing is preserved alongside any edited work. This allows analysts the option to return to the origonal form in the case or any unforseen errors during the investigation process. The majority of this notebook contains details on how to prepare data for analysis. The analysis itself is a shorter and easy process, that is if the preparation was correct. These skills used in this notebook are an invaluable element in the field of data analytics.

# %% [markdown]
# <br>
#
# # References:
#
# ***
#
# All references and code used in this notebook have been sourced in Oct/Nov/Dec 2021 from the following webpages:
#
#
# - https://github.com/ianmcloughlin/cao-points/blob/main/cao-points-analysis.ipynb
#
#
# - https://www.cao.ie/
#
#
# - https://realpython.com/regex-python/
#
#
# - https://www.pythonforbeginners.com/requests/using-requests-in-python
#
#
# - https://docs.python.org/3/library/re.html
#
#
# - https://www.geeksforgeeks.org/python-datetime-module/
#
#
# - https://mode.com/python-tutorial/libraries/pandas/#:~:text=Pandas%20is%20a%20Python%20library%20for%20data%20analysis.&text=Pandas%20is%20built%20on%20top,NumPy%27s%20methods%20with%20less%20code.
#
#
# - https://docs.python.org/3/library/urllib.request.html
#
#
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html
#
#
# - https://towardsdatascience.com/top-10-magic-commands-in-python-to-boost-your-productivity-1acac061c7a9
#
#
# - https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
#
# - https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.RcParams
#
#
# - https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline
#
#
# - https://realpython.com/regex-python-part-2/
#
#
# - https://www.mygreatlearning.com/blog/regular-expression-in-python/
#
#
# - https://docs.python-requests.org/en/latest/user/quickstart/#make-a-request
#
#
# - https://howchoo.com/g/ywi5m2vkodk/working-with-datetime-objects-and-timezones-in-python
#
#
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html
#
#
# - https://stackoverflow.com/questions/16870648/python-read-website-data-line-by-line-when-available
#
#
# - https://www.geeksforgeeks.org/python-urllib-module/
#
#
# - https://strftime.org/
#
#
# - http://www.cao.ie/index.php?page=points&p=2021
#
#
# - https://docs.python-requests.org/en/latest/user/quickstart/#make-a-request
#
#
# - https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
#
#
# - https://stackoverflow.com/questions/4657416/difference-between-encoding-and-encryption
#
#
# - https://en.wikipedia.org/wiki/Windows-1252#:~:text=Windows%2D1252%20or%20CP%2D1252,Spanish%2C%20French%2C%20and%20German.
#
#
# - https://www.pythonforbeginners.com/files/with-statement-in-python
#
#
# - https://www.tutorialspoint.com/Why-do-we-use-re-compile-method-in-Python-regular-expression
#
#
# - https://www.w3schools.com/python/python_conditions.asp
#
#
# - https://www.w3schools.com/python/ref_string_isdigit.asp
#
#
# - https://www.geeksforgeeks.org/re-fullmatch-function-in-python/
#
#
# - https://www.w3schools.com/python/ref_string_strip.asp
#
#
# - https://stackoverflow.com/questions/12683201/python-re-split-to-split-by-spaces-commas-and-periods-but-not-in-cases-like
#
#
# - https://www.w3schools.com/python/ref_func_len.asp
#
#
# - http://www.cao.ie/index.php?page=points&p=2020
#
#
# - https://programmer.ink/think/how-to-use-urlretrieve-in-python-3.html
#
#
# - https://www.geeksforgeeks.org/python-pandas-series-to_csv/
#
#
# - http://www.cao.ie/index.php?page=points&p=2019
#
#
# - https://www.videostudiopro.com/en/?link=wm
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.concat.html
#
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html#pandas.DataFrame.drop_duplicates
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html
#
#
# - https://stackoverflow.com/questions/44530047/why-is-my-numeric-data-being-treated-as-an-object
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
#
#
# - https://towardsdatascience.com/5-methods-to-check-for-nan-values-in-in-python-3f21ddd17eed#:~:text=How%20to%20check%20if%20a%20single%20value%20is%20NaN%20in%20python.&text=NaN%20stands%20for%20Not%20A,major%20problems%20in%20Data%20Analysis.
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.size.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html
#
#
# - https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_Ireland
#
#
# - https://www.cao.ie/#:~:text=Closing%20Date%20for%20Applications%20is%20the%201st%20February%20at%2017%3A00.
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html
#
#
# - https://www.cuemath.com/data/mean/
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html
#
#
# - https://www.mathsisfun.com/data/standard-deviation-formulas.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.min.html?highlight=df%20min
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.max.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html#pandas.DataFrame.iloc
#
#
# - https://www.datacamp.com/community/tutorials/python-list-index
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.line.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
#
#
# - https://docs.python.org/3/library/datetime.html
#
#
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html
#
#
# - https://stackoverflow.com/questions/38277928/remove-special-characters-in-pandas-dataframe
#
#
# - https://cheatography.com/davechild/cheat-sheets/regular-expressions/
#
# <br>

# %% [markdown]
# ***
#
# # End
